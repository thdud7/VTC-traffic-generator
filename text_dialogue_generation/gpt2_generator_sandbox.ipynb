# %% [markdown]
# # Test notebook for creating text content with GPT-2
# [GPT-2](https://github.com/openai/gpt-2)

# %%
# !python ./src/generate_unconditional_samples.py --top_k 40 --model_name=124M
# Out:
# /home/dave/.virtualenvs/gpt-2_ENV/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/dave/.virtualenvs/gpt-2_ENV/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/dave/.virtualenvs/gpt-2_ENV/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/dave/.virtualenvs/gpt-2_ENV/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/dave/.virtualenvs/gpt-2_ENV/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/dave/.virtualenvs/gpt-2_ENV/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2021-03-25 20:16:39.155125: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-03-25 20:16:39.189332: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2100940000 Hz
# 2021-03-25 20:16:39.190456: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x555f376e1800 executing computations on platform Host. Devices:
# 2021-03-25 20:16:39.190505: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# WARNING:tensorflow:From /home/dave/.virtualenvs/gpt-2_ENV/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/dave/projects/SEARCHLIGHT/repos/vtc/text_dialogue_generation/gpt-2/src/sample.py:64: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/dave/projects/SEARCHLIGHT/repos/vtc/text_dialogue_generation/gpt-2/src/sample.py:67: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.random.categorical instead.
# WARNING:tensorflow:From /home/dave/.virtualenvs/gpt-2_ENV/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2021-03-25 20:16:42.245995: W tensorflow/core/framework/allocator.cc:124] Allocation of 154389504 exceeds 10% of system memory.
# 2021-03-25 20:16:58.390335: W tensorflow/core/framework/allocator.cc:124] Allocation of 21823488 exceeds 10% of system memory.
# 2021-03-25 20:16:58.445797: W tensorflow/core/framework/allocator.cc:124] Allocation of 21897216 exceeds 10% of system memory.
# 2021-03-25 20:16:58.499946: W tensorflow/core/framework/allocator.cc:124] Allocation of 21970944 exceeds 10% of system memory.
# 2021-03-25 20:16:58.553758: W tensorflow/core/framework/allocator.cc:124] Allocation of 22044672 exceeds 10% of system memory.
# ======================================== SAMPLE 1 ========================================
#
# If you're looking, please click on the following links to learn more about the new products and see our new list of available products.
#
# Please remember that you only need to click the link in the left-hand column, to go to our product page, or use this link once a month to follow our YouTube channel.
#
# New, Better, etc. Items From Walmart
#
# When you enter your shopping location, you can filter those items by categories to get your shopping basket name & category. You can also set your order status so that the items we give you have the same names and category for your order.
#
# If you're looking for other products (like the discount chain coupons?), I would strongly suggest looking for any items from Walmart that sell directly to you.
#
# We also offer items through your local Walmart for sale.
#
# The products that Walmart sells are great for small children & small businesses, and are often a part of your local food supply chain
#
# If you'd like to learn further about Walmart's free products program, follow us on Twitter (@WalmartFree). Also check out the Walmart Consumer Safety Center.
#
# Here's a look at some of the new Walmart offers.
#
# For the latest news about the free products, check out Walmart.
#
# I've also been following these amazing videos by Viacom.
#
# The free Disney Infinity Box
#
# Check out these great Disney Infinity games.
#
# Disney Infinity's Box will offer you everything you need:
#
# - New Disney Infinity Toy Box
#
# - Exclusive Cartoon Network Exclusive Box! (includes a Disney Infinity Box)
#
# - Special Disney Infinity Character Box, with Disney Infinity Box, Extra Toys and more! (Includes Toys and more!)
#
# - Disney Infinity Box Poster
#
# - Extra Nintendo Virtual Console Card
#
# - Special Disney Infinity Collector Package, including the box!
#
# Check out our review of Disney Infinity.
#
# Check out our video review of Disney Infinity.
#
# Disney Infinity is coming to PS4, Steam, Mac and PC in 2016!!
#
# Here are three different reviews of Disney Infinity including the Disney Infinity box!
#
# Here are our other reviews of Disney Infinity including the Disney Infinity Box!
#
# Disney Infinity Box is coming to PS4, Steam, Mac, PC and Android.
#
# Disney Infinity: Journey Begins
#
# If you haven't already done just then, the game is coming to the next versions, PS4 and PC. These 2 games will be free and available on a limited basis for all users!
#
# If you want to learn more about Disney Infinity for Windows PCs check out the Disney Infinity page on the Xbox site.
#
# Disney Infinity for iPad comes to iOS.
#
# Disney Infinity 3G is coming to iPad and the iPhone!
#
# New Disney Infinity toys
#
# New Disney Infinity Toys
#
# New Disney Infinity: Home on the Hill
#
# Here we have the latest Disney Infinity 4G mobile phone app.
#
# We've also updated the Disney Infinity 3G app with some special and exclusive Disney Infinity accessories. You won't find a better place to get your hands on the toys of the new game.
#
# Here's a look at our favorite Disney Infinity games.<|endoftext|>MOSCOW (Reuters) - A Moscow court on Monday struck down a court order to allow Russian state-controlled TV station RT to broadcast an audio recording of an interview with the Kremlin's head of state Sergei Lavrov.
#
# Russian President Vladimir Putin speaks during a news conference held at his residence near Moscow, Russia May 18, 2017. REUTERS/Sergei Karpukhin
#
# The court ordered that journalists must show their audio at least four times, while RT had to give the channel a 20-second clip of video.
#
# The Kremlin's reaction followed the Kremlin on Monday rejected such arguments as a violation of its press freedom laws and a potential threat to Russian security.
#
# The Moscow court said the decision was in breach of its "protective orders" to protect journalists from "illegal interference in foreign affairs".
#
# Russia has a relatively weak judiciary and a reputation for using its law enforcement authority to impose its lawlessness. It was unable to hold the court on Nov. 17 to allow the broadcast of the interview, it said.
#
# Moscow does not accept Russian President Vladimir Putin's call for the lifting of sanctions imposed on Russia following the July 19 annexation of Crimea.
#
# Kremlin spokeswoman Maria Zakharova said the court had already upheld a 2015 ruling by a federal judge in Siberia that would have barred RT from airing in Russia under its state-run channel RT.
#
# She accused "the court" of "imposing anti-Russian measures to stifle free expression in Russia".
#
# "The court has already decided, after careful consideration, that the station will be compelled to broadcast the interview in accordance with international law," she said.
#
# The Kremlin condemned the "illegal and arbitrary ruling" in the Siberian town of Novoazovsk, where
# ^C

# %%
# %cd gpt-2
# Out:
# /home/dave/projects/SEARCHLIGHT/repos/vtc/text_dialogue_generation/gpt-2
