# %% [markdown]
# # Colaboratory notebook for collecting samples from GPT 2
# Using Cloud GPU

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !nvidia-smi
# Out:
# Thu Apr 15 06:55:13 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import files

# %% [markdown]
# Start with standard GPT-2

# %%
# !git clone -l -s git://github.com/openai/gpt-2 gpt2
# %cd gpt2
# Out:
# Cloning into 'gpt2'...
# ...
# remote: Enumerating objects: 233, done.
# remote: Total 233 (delta 0), reused 0 (delta 0), pack-reused 233
# Receiving objects: 100% (233/233), 4.38 MiB | 8.64 MiB/s, done.
# Resolving deltas: 100% (124/124), done.
# /content/gpt2

# %%
files.upload()
# Out:
#      <input type="file" id="files-e06a8bf3-fbab-44ff-8839-3a9a6d890d26" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e06a8bf3-fbab-44ff-8839-3a9a6d890d26">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving generate_unconditional_samples.py to generate_unconditional_samples.py
# ...

# %% [markdown]
# Copy from local environment
#
# ```
# # generate_unconditional_samples.py
# ```

# %%
# !tail src/generate_unconditional_samples.py
# Out:
#                 generated += batch_size
#                 text = enc.decode(out[i])
#                 print("=" * 40 + " SAMPLE " + str(generated) + " " + "=" * 40)
#                 print(text)
#                 full_output.append(text)
#     return full_output
#
# if __name__ == '__main__':
#     fire.Fire(sample_model)

# %%
# !python download_model.py 1558M
# Out:
# Fetching checkpoint: 1.00kit [00:00, 916kit/s]
# Fetching encoder.json: 1.04Mit [00:00, 2.72Mit/s]
# Fetching hparams.json: 1.00kit [00:00, 910kit/s]
# Fetching model.ckpt.data-00000-of-00001: 6.23Git [16:03, 6.47Mit/s]
# Fetching model.ckpt.index: 21.0kit [00:00, 445kit/s]
# Fetching model.ckpt.meta: 1.84Mit [00:00, 2.94Mit/s]
# Fetching vocab.bpe: 457kit [00:00, 1.36Mit/s]

# %%
# !ls models
# Out:
# 1558M

# %%
# !pip install fire
# Out:
# ...
#      |████████████████████████████████| 92kB 5.8MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115928 sha256=e070b643b03150b60b111b14de8f26055f2b425010df58e1d3e04e616566ac33
#   Stored in directory: /root/.cache/pip/wheels/af/19/30/1ea0cad502dcb4e66ed5a690279628c827aea38bbbab75d5ed
# Successfully built fire
# ...

# %%
# !python ./src/generate_unconditional_samples.py --top_k 40 --model_name=124M

# %%
# %env PYTHONPATH=/content/gpt2/src
# Out:
# env: PYTHONPATH=/content/gpt2/src

# %%
# !echo $PYTHONPATH
# Out:
# /content/gpt2/src

# %%
import generate_unconditional_samples

# %%
gpt2_output = generate_unconditional_samples.sample_model(models_dir= '/content/gpt2/models', top_k = 40, model_name = '1558M', nsamples=25)
# Out:
# INFO:tensorflow:Restoring parameters from /content/gpt2/models/1558M/model.ckpt

# %%
pickle.dump(gpt2_output, open('gpt2_out.pkl', 'wb'))

# %%
from google.colab import files

# %%
files.download('testout.txt')
