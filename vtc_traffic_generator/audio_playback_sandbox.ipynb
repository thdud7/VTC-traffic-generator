# %% [markdown]
# # Audio playback sandbox
# Sandbox for developing code to play audio files through virtual microphone devices

# %%
import ffmpeg
import time
import sys
import pulsectl
import subprocess

# %%
ls /home/dave/projects/SEARCHLIGHT/VTC/VTC_audio_tracks/

# %%
ls

# %%
try:
    process = (
        ffmpeg
        .input('/home/dave/Desktop/line_9.flac')
        .output('virtual_speaker', format='pulse', device='virtual_speaker')
        )
    process = process.run(capture_stdout=True, capture_stderr=True)
    
except ffmpeg.Error as e:
    print('stdout:', e.stdout.decode('utf8'))
    print('stderr:', e.stderr.decode('utf8'))
    raise e

# %% [markdown]
# Initialize PulseAudio devices
#
# `$ pactl load-module module-null-sink sink_name="virtual_speaker" sink_properties=device.description="virtual_speaker"`
#
# `$ pactl load-module module-remap-source master="virtual_speaker.monitor" source_name="virtual_mic" source_properties=device.description="virtual_mic"`

# %%
subprocess.run('pactl load-module module-null-sink sink_name="virtual_speaker" sink_properties=device.description="virtual_speaker"', capture_output=True, shell=True)
subprocess.run('pactl load-module module-remap-source master="virtual_speaker.monitor" source_name="virtual_mic" source_properties=device.description="virtual_mic"', capture_output=True, shell=True)
# Out:
# CompletedProcess(args='pactl load-module module-remap-source master="virtual_speaker.monitor" source_name="virtual_mic" source_properties=device.description="virtual_mic"', returncode=0, stdout=b'26\n', stderr=b'')

# %%
pulse = pulsectl.Pulse()

# %%
a=pulse.sink_list()

# %%
a
# Out:
# [<PulseSinkInfo at 7f8860727730 - description='Built-in Audio Analog Stereo', index=0, mute=0, name='alsa_output.pci-0000_00_1f.3.analog-stereo', channels=2, volumes=[30% 30%]>,
#  <PulseSinkInfo at 7f8860739280 - description='virtual_speaker', index=1, mute=0, name='virtual_speaker', channels=2, volumes=[80% 80%]>]

# %%
b=pulse.source_list()

# %%
b
# Out:
# [<PulseSourceInfo at 7f886071c0d0 - description='Webcam C270 Mono', index=0, mute=0, name='alsa_input.usb-046d_0825_DA4DC4D0-02.mono-fallback', channels=1, volumes=[100%]>,
#  <PulseSourceInfo at 7f886071c6d0 - description='Monitor of Built-in Audio Analog Stereo', index=1, mute=1, name='alsa_output.pci-0000_00_1f.3.analog-stereo.monitor', channels=2, volumes=[100% 100%]>,
#  <PulseSourceInfo at 7f8860727a60 - description='Built-in Audio Analog Stereo', index=2, mute=0, name='alsa_input.pci-0000_00_1f.3.analog-stereo', channels=2, volumes=[14% 14%]>,
#  <PulseSourceInfo at 7f886071c100 - description='Monitor of virtual_speaker', index=3, mute=0, name='virtual_speaker.monitor', channels=2, volumes=[100% 100%]>,
#  <PulseSourceInfo at 7f88600ab310 - description='virtual_mic', index=4, mute=0, name='virtual_mic', channels=2, volumes=[99% 99%]>]

# %%
pulse.volume_set_all_chans(a[1], .8)

# %%
a[0]
# Out:
# <PulseSinkInfo at 7f8860727730 - description='Built-in Audio Analog Stereo', index=0, mute=0, name='alsa_output.pci-0000_00_1f.3.analog-stereo', channels=2, volumes=[30% 30%]>

# %% [markdown]
# Setting device volume and mute status

# %%
for sink in pulse.sink_list():
    pulse.volume_set_all_chans(sink, .7)
    pulse.mute(sink, False)

# %%
for source in pulse.source_list():
    pulse.volume_set_all_chans(source, .7)
    pulse.mute(source, False)

# %% [markdown]
# #
